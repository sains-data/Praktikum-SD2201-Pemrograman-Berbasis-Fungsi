# %% [markdown]
# # TUGAS PRAKTIKUM KELOMPOK 2 PBF RC
#
# Tugas Modul 3 Praktikum PBF RC
# 1. Abit Ahmad Oktarian - 122450042
# 2. Alya Nurul Islami Pasha - 122450033
# 3. David Boby C. Nainggolan - 122450048
# 4. Dearni Monika - 122450075
# 5. Nabil Anilda Zahrah - 122450063
# 6. Yohana Manik - 122450126

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e97c4a4b-3cf3-4d0a-84a2-672be8d51190" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e97c4a4b-3cf3-4d0a-84a2-672be8d51190">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
data = pd.read_excel(io.BytesIO(uploaded['Jumlah Balita Stunting Menurut Kabupaten_Kota (5).xlsx']))

# %%
data.head()
# Out:
#              Unnamed: 0  Sangat Pendek  Sangat Pendek.1  Sangat Pendek.2  \
# 0               wilayah         2021.0           2022.0           2023.0
# 1           Sumba Barat          518.0            639.0            386.0
# 2           Sumba Timur         1024.0            779.0            636.0
# 3                Kupang         1721.0           1494.0           1094.0
# 4  Timor Tengah Selatan         4002.0           3653.0           3108.0
#
#    Pendek  Pendek.1  Pendek.2   Normal  Normal.1  Normal.2  Tinggi  Tinggi.1  \
# 0  2021.0    2022.0    2023.0   2021.0    2022.0    2023.0  2021.0    2022.0
# 1  1561.0    1972.0     905.0   6696.0    8554.0    9393.0    33.0      29.0
# 2  2750.0    2699.0    2041.0  15958.0   19815.0   19977.0    71.0      31.0
# 3  4953.0    4624.0    2778.0  23052.0   24518.0   25968.0   188.0     136.0
# 4  9121.0    7989.0    5816.0  27681.0   29457.0   31092.0   133.0      38.0
#
# ...

# %%
def mean(df):
  return sum(data) / len(data)
def median(df):
  sorted_data = sorted(data)
  n = len(data)
  mid = n // 2
  return (sorted_data[mid] + sorted_data[-mid-1]) / 2 if n % 2 == 0 else sorted_data[mid]
def mode(df):
  frequency = {}
  for item in data:
    frequency[item] = frequency.get(item, 0) + 1
    max_frequency = max(frequency.values())
    return [item for item, freq in frequency.item() if freq == max_frequency]

# %%
df.skew()
# Out:
# <ipython-input-83-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# Sangat Pendek          4.612676
# Sangat Pendek.1        4.577982
# Sangat Pendek.2        4.543547
# Pendek                 4.735378
# Pendek.1               4.719350
# Pendek.2               4.678567
# Normal                 4.816681
# Normal.1               4.822430
# Normal.2               4.822085
# Tinggi                 3.488097
# Tinggi.1               3.721714
# Tinggi.2               4.392867
# Stunting               4.712320
# Stunting.1             4.693645
# Stunting.2             4.653049
# Persentase Stunting    4.897259
# Unnamed: 17            4.897546
# Unnamed: 18            4.897284
# dtype: float64

# %%
df.kurtosis()
# Out:
# <ipython-input-84-c7edf97eb14c>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.kurtosis()
# Sangat Pendek          21.944837
# Sangat Pendek.1        21.716370
# Sangat Pendek.2        21.471048
# Pendek                 22.842989
# Pendek.1               22.744280
# Pendek.2               22.447985
# Normal                 23.439008
# Normal.1               23.480634
# Normal.2               23.476968
# Tinggi                 11.981464
# Tinggi.1               14.248512
# Tinggi.2               20.033680
# Stunting               22.670765
# Stunting.1             22.553874
# Stunting.2             22.255499
# Persentase Stunting    23.988294
# Unnamed: 17            23.990244
# Unnamed: 18            23.988436
# dtype: float64

# %%
# Menghitung skewness
skewness = df.skew()

# Menghitung kurtosis
kurtosis = df.kurtosis()

# Tampilkan hasil
print('Skewness:', skewness)
print('Kurtosis:', kurtosis)
# Out:
# Skewness: Sangat Pendek          4.612676
# Sangat Pendek.1        4.577982
# Sangat Pendek.2        4.543547
# Pendek                 4.735378
# Pendek.1               4.719350
# Pendek.2               4.678567
# Normal                 4.816681
# Normal.1               4.822430
# Normal.2               4.822085
# Tinggi                 3.488097
# Tinggi.1               3.721714
# Tinggi.2               4.392867
# Stunting               4.712320
# Stunting.1             4.693645
# Stunting.2             4.653049
# Persentase Stunting    4.897259
# Unnamed: 17            4.897546
# Unnamed: 18            4.897284
# dtype: float64
# Kurtosis: Sangat Pendek          21.944837
# Sangat Pendek.1        21.716370
# Sangat Pendek.2        21.471048
# Pendek                 22.842989
# Pendek.1               22.744280
# Pendek.2               22.447985
# Normal                 23.439008
# Normal.1               23.480634
# Normal.2               23.476968
# Tinggi                 11.981464
# ...
