# %%
data1=pd.read_excel('/content/datapbf.xlsx')
data1
# Out:
#     Rata-rata lama sekolah
# 0                     8.07
# 1                     7.54
# 2                     7.70
# 3                     7.77
# 4                     7.69
# 5                     8.34
# 6                     7.71
# 7                     7.55
# 8                     7.71
# 9                     8.39
# 10                    7.08
# 11                    7.39
# 12                    8.19
# 13                   10.95
# 14                   10.97
# 15                    8.08

# %%
import pandas as pd

def main():
  #mengambil kolom
  kolom= data1['Rata-rata lama sekolah']
  #memanggil fungsi
  print("Varians",varians(kolom))
  print("Standar Deviasi:",stdev(kolom))
#menghitung varians dan standar deviasi dari kolom yang dipilih
def varians(data):
    mu = data.mean()
    return sum((x - mu) ** 2 for x in data) / (len(data) - 1)

def stdev(data):
    return varians(data) ** 0.5

main()
# Out:
# Varians 1.284399583333333
# Standar Deviasi: 1.1333135414938502
